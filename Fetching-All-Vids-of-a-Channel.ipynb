# %%
from apiclient.discovery import build 
import pandas as pd

# %%
api_key = "AIzaSyDxJbSEPodYNzB6Fuk4hsZHnwH08J8uc1I"
youtube = build('youtube','v3',developerKey = api_key)

# %%
res = youtube.channels().list(id='UCWv7vMbMWH4-V0ZXdmDpPBA',
                              part='contentDetails').execute()

# %%
res    # From here copy the id of 'uploads'
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '"Dn5xIderbhAnUk5TAW0qkFFir0M/PdraBsOVe0mtpa6gNdlk9cUbC0g"',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '"Dn5xIderbhAnUk5TAW0qkFFir0M/c3CgizCumrVV15rSBy7TeJdv9uw"',
#    'id': 'UCWv7vMbMWH4-V0ZXdmDpPBA',
#    'contentDetails': {'relatedPlaylists': {'uploads': 'UUWv7vMbMWH4-V0ZXdmDpPBA',
#      'watchHistory': 'HL',
#      'watchLater': 'WL'}}}]}

# %%
res = youtube.playlistItems().list(playlistId='UUWv7vMbMWH4-V0ZXdmDpPBA',
                                   part='snippet',
                                   maxResults=50).execute()
res
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': '"Dn5xIderbhAnUk5TAW0qkFFir0M/qt_PL7TneTvjKrwiO__3hsHFa4s"',
#  'nextPageToken': 'CDIQAA',
#  'pageInfo': {'totalResults': 146, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': '"Dn5xIderbhAnUk5TAW0qkFFir0M/-T-LRzmwwtD5Ru0FSiiD_aHgJvc"',
#    'id': 'VVVXdjd2TWJNV0g0LVYwWlhkbURwUEJBLjAtUzVhMGVYUG9j',
#    'snippet': {'publishedAt': '2020-05-09T17:03:52.000Z',
#     'channelId': 'UCWv7vMbMWH4-V0ZXdmDpPBA',
#     'title': 'React Native Tutorial for Beginners  [2020]',
# ...

# %%
# Function for getting all videos of a channel 

def get_channel_videos(channel_id):
    res = youtube.channels().list(id=channel_id,
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None 
    
    while 1:
        res = youtube.playlistItems().list(playlistId=playlist_id,
                                   part='snippet',
                                   maxResults=50,
                                   pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None:
            break
            
    return videos

# %%
videos = get_channel_videos('UCWv7vMbMWH4-V0ZXdmDpPBA')

# %%
videos
# Out:
# [{'kind': 'youtube#playlistItem',
#   'etag': '"Dn5xIderbhAnUk5TAW0qkFFir0M/-T-LRzmwwtD5Ru0FSiiD_aHgJvc"',
#   'id': 'VVVXdjd2TWJNV0g0LVYwWlhkbURwUEJBLjAtUzVhMGVYUG9j',
#   'snippet': {'publishedAt': '2020-05-09T17:03:52.000Z',
#    'channelId': 'UCWv7vMbMWH4-V0ZXdmDpPBA',
#    'title': 'React Native Tutorial for Beginners  [2020]',
# ...

# %%
len(videos)
# Out:
# 146

# %%
#Filtering the videos list

for video in videos:
    vid = video['snippet']['title'],video['id']
    print(vid)
# Out:
# ('React Native Tutorial for Beginners  [2020]', 'VVVXdjd2TWJNV0g0LVYwWlhkbURwUEJBLjAtUzVhMGVYUG9j')
# ('Redux Tutorial - Learn Redux from Scratch', 'VVVXdjd2TWJNV0g0LVYwWlhkbURwUEJBLnBvUVhOcDlJdEw0')
# ('Top Programming Languages in 2020', 'VVVXdjd2TWJNV0g0LVYwWlhkbURwUEJBLmJqRnZjRmpKcEUw')
# ('Design Patterns in Plain English | Mosh Hamedani', 'VVVXdjd2TWJNV0g0LVYwWlhkbURwUEJBLk5VXzFTdE41VGtr')
# ('Why I Left My Job as a Senior Software Engineer | Mosh Hamedani', 'VVVXdjd2TWJNV0g0LVYwWlhkbURwUEJBLjhUbkJaOHJvbTlj')
# ('Jingle Bells Piano (Jazz) | Christmas Music', 'VVVXdjd2TWJNV0g0LVYwWlhkbURwUEJBLlFBczI1X2hNaFpZ')
# ("Mosh's Christmas Present to You (2019)", 'VVVXdjd2TWJNV0g0LVYwWlhkbURwUEJBLnE0TUVLVFZ4ZzBj')
# ('Data Structures and Algorithms in Java', 'VVVXdjd2TWJNV0g0LVYwWlhkbURwUEJBLkJCcEFteFVfTlFv')
# ('New Course: Data Structures & Algorithms [Part 2]', 'VVVXdjd2TWJNV0g0LVYwWlhkbURwUEJBLmNpZmlyeTh5b2Fv')
# ...

# %%
# For writing the required output in a csv file  

import csv

# %%
with open('videos.csv','w') as vid_csv:
    writer = csv.writer(vid_csv,delimiter=',',lineterminator='\n')
    writer.writerow(['Video_Title','Video_ID'])
    for video in videos:
        row = video['snippet']['title'],video['id']
        writer.writerow(row)

# %%
df = pd.read_csv('videos.csv')
df
# Out:
#                                            Video_Title  \
# 0          React Native Tutorial for Beginners  [2020]
# 1            Redux Tutorial - Learn Redux from Scratch
# 2                    Top Programming Languages in 2020
# 3     Design Patterns in Plain English | Mosh Hamedani
# 4    Why I Left My Job as a Senior Software Enginee...
# ..                                                 ...
# 141  Backbone.js Tutorial Part 3 - Backbone.js Mode...
# 142  Backbone.js Tutorial Part 2 - Backbone.js Mode...
# 143  Backbone.js Tutorial Part 1 - Backbone.js Mode...
# 144  Visual Studio Keyboard Shortcuts that Speed Up...
# 145  6 Visual Studio Tips to Increase Your Producti...
#
#                                              Video_ID
# 0    VVVXdjd2TWJNV0g0LVYwWlhkbURwUEJBLjAtUzVhMGVYUG9j
# 1    VVVXdjd2TWJNV0g0LVYwWlhkbURwUEJBLnBvUVhOcDlJdEw0
# 2    VVVXdjd2TWJNV0g0LVYwWlhkbURwUEJBLmJqRnZjRmpKcEUw
# 3    VVVXdjd2TWJNV0g0LVYwWlhkbURwUEJBLk5VXzFTdE41VGtr
# ...
