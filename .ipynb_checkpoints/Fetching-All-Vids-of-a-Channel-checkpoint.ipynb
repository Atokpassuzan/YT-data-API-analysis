# %%
from apiclient.discovery import build

# %%
api_key = "AIzaSyDxJbSEPodYNzB6Fuk4hsZHnwH08J8uc1I"
youtube = build('youtube','v3',developerKey = api_key)

# %%
res = youtube.channels().list(id='UCAE392C3hYv6oLIkkjsaUWw',
                              part='contentDetails').execute()

# %%
res    # From here copy the id of 'uploads'
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'tduxZqnJ9y7OhjVaaC8VWhGdVaY',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '4ulOCwrmbk-iUPDRk_LDqUK6i2c',
#    'id': 'UCAE392C3hYv6oLIkkjsaUWw',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'favorites': '',
#      'uploads': 'UUAE392C3hYv6oLIkkjsaUWw',
#      'watchHistory': 'HL',
#      'watchLater': 'WL'}}}]}

# %%
res = youtube.playlistItems().list(playlistId='UUAE392C3hYv6oLIkkjsaUWw',
                                   part='snippet',
                                   maxResults=50).execute()

# %%
def get_channel_videos(channel_id):
    res = youtube.channels().list(id=channel_id,
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    videos = []
    next_page_token = None 
    
    while 1:
        res = youtube.playlistItems().list(playlistId='playlist_id',
                                   part='snippet',
                                   maxResults=50,
                                   pageToken=next_page_token).execute()
        videos += res['items']
        next_page_token = res.get('nextPageToken')
        
        if next_page_token is None:
            break
            
    return videos

# %%
videos = get_channel_videos('UCAE392C3hYv6oLIkkjsaUWw')
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# <ipython-input-26-1ad7b852c0d2> in <module>
# ----> 1 videos = get_channel_videos('UCAE392C3hYv6oLIkkjsaUWw')
#
# <ipython-input-24-8aa1dc5ba95e> in get_channel_videos(channel_id)
#       1 def get_channel_videos(channel_id):
# ----> 2     res = youtube.channels().list(id=channel_id,
#       3                               part='contentDetails').execute()
#       4     playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
#       5
#
# c:\users\dell\appdata\local\programs\python\python38-32\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
# ...

# %%
res
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': '"Dn5xIderbhAnUk5TAW0qkFFir0M/CWse9C0y-M7w1nxRFXqxR9eeZXU"',
#  'pageInfo': {'totalResults': 23, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': '"Dn5xIderbhAnUk5TAW0qkFFir0M/kXGaW42bFhN1Kxl4f8l201WlndU"',
#    'id': 'VVVBRTM5MkMzaFl2Nm9MSWtranNhVVd3LkdUZWRrUkxRY2tN',
#    'snippet': {'publishedAt': '2020-04-15T07:05:02.000Z',
#     'channelId': 'UCAE392C3hYv6oLIkkjsaUWw',
#     'title': "Arthur Gunn -  Pralaya 'A' (Live / Dec 31 / 2018)",
#     'description': 'This video was taken on the welcome home show of "Grahan Tour" at BnC. Thank you all of the good&wicked friends and strangers that made this show and the tour possible.\n\nVideo credit: Aabhash Shrestha\n\nAll.Rights.Reserved',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GTedkRLQckM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GTedkRLQckM/mqdefault.jpg',
# ...
