# %%
from apiclient.discovery import build 
from datetime import datetime

# %%
api_key = "AIzaSyDxJbSEPodYNzB6Fuk4hsZHnwH08J8uc1I"
youtube = build('youtube','v3',developerKey = api_key)

# %%
start_time = datetime(year=2005,month=1,day=1).strftime('%Y-%m-%dT%H:%M:%SZ')
end_time = datetime(year=2006,month=1,day=1).strftime('%Y-%m-%dT%H:%M:%SZ')

# %%
req = youtube.search().list(q='',
                            part='snippet',
                            type='video',
                            maxResults=20,
                            publishedAfter=start_time,
                            publishedBefore=end_time)

# %%
res = req.execute()

# %%
res
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'prqBiT9QYIycuBSPpMzXR9c59qA',
#  'nextPageToken': 'CBQQAA',
#  'regionCode': 'NP',
#  'pageInfo': {'totalResults': 369404, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'TpJHR7IbJU3MuJ7m47jd8QJ-HI4',
#    'id': {'kind': 'youtube#video', 'videoId': 'UMf40daefsI'},
#    'snippet': {'publishedAt': '2005-11-19T10:38:22Z',
#     'channelId': 'UCY30JRSgfhYXA6i6xX1erWg',
#     'title': 'Mortal Kombat Theme',
#     'description': "Everyone's favorite fighting video game's theme song now has a music video. Watch this video in higher quality & download at http://smosh.com ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UMf40daefsI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UMf40daefsI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UMf40daefsI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Smosh',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-11-19T10:38:22Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'N7Tbi5lVokGmel6ZbQJagziq2Aw',
#    'id': {'kind': 'youtube#video', 'videoId': 'jhxIjRO6WjI'},
#    'snippet': {'publishedAt': '2005-11-14T09:45:25Z',
#     'channelId': 'UCUB5LxaICELk7lP5r2kpJgQ',
#     'title': 'celine dion ft. josh groban, the prayer',
#     'description': 'my favorite song.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jhxIjRO6WjI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jhxIjRO6WjI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/jhxIjRO6WjI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'jlhet',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-11-14T09:45:25Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'jV3PP3P43l9i5w0Bjo2DPKxe4B8',
#    'id': {'kind': 'youtube#video', 'videoId': 'Nt2OVAgkHBc'},
#    'snippet': {'publishedAt': '2005-12-24T01:13:43Z',
#     'channelId': 'UCCHcEUksSVKsRDH86j77Ntg',
#     'title': 'Just 2 Guyz',
#     'description': 'Check out more from these 2 guyz: http://smarturl.it/Just2GuyzVids Brought to you by: http://www.thelonelyisland.com/ You are free to copy, share and remix this ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Nt2OVAgkHBc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Nt2OVAgkHBc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Nt2OVAgkHBc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'thelonelyisland',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-12-24T01:13:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'CqUvf5Cb-TTWbscX1jFuLDHTMbc',
#    'id': {'kind': 'youtube#video', 'videoId': '_r0n9Dv6XnY'},
#    'snippet': {'publishedAt': '2005-11-02T22:02:48Z',
#     'channelId': 'UCfcDEF_s7zjl3ZM_6fCZ_vg',
#     'title': 'Baltimora - Tarzan Boy',
#     'description': 'temazo de Baltimora super ochentero.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_r0n9Dv6XnY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_r0n9Dv6XnY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_r0n9Dv6XnY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'nailofgilead',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-11-02T22:02:48Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'dQNmLWhO8Qw1Rn66ssCxynmjxH8',
#    'id': {'kind': 'youtube#video', 'videoId': 'rH9giCg3Nro'},
#    'snippet': {'publishedAt': '2005-12-24T02:45:00Z',
#     'channelId': 'UCCHcEUksSVKsRDH86j77Ntg',
#     'title': 'Stork Patrol',
#     'description': 'Brought to you by: http://www.thelonelyisland.com/ You are free to copy, share and remix this video, under these conditions: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rH9giCg3Nro/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/rH9giCg3Nro/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/rH9giCg3Nro/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'thelonelyisland',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-12-24T02:45:00Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Rj0HZYe_g1iukS6aEOZxv4L-gOU',
#    'id': {'kind': 'youtube#video', 'videoId': 'qn7duAZjP8w'},
#    'snippet': {'publishedAt': '2005-12-24T02:30:34Z',
#     'channelId': 'UCCHcEUksSVKsRDH86j77Ntg',
#     'title': 'Ka-Blamo!',
#     'description': 'Brought to you by: http://www.thelonelyisland.com/ You are free to copy, share and remix this video, under these conditions: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qn7duAZjP8w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qn7duAZjP8w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qn7duAZjP8w/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'thelonelyisland',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-12-24T02:30:34Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'rrT5xJp1SiY0pH0e0s-YX_HEdu0',
#    'id': {'kind': 'youtube#video', 'videoId': 'm1Q8Dirdzxk'},
#    'snippet': {'publishedAt': '2005-12-28T19:33:46Z',
#     'channelId': 'UC9PgszLOAWhQC6orYejcJlw',
#     'title': 'Aaron Kyro www.brailleskateboarding.com',
#     'description': 'http://www.brailleskateboarding.com Subscribe! Here is my new part hope you like it! - http://www.youtube.com/watch?v=vKAPbJMhdyo.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/m1Q8Dirdzxk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/m1Q8Dirdzxk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/m1Q8Dirdzxk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Braille Skateboarding',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-12-28T19:33:46Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '1Jmg0PY-I9QWEBaod94SPWQuG-E',
#    'id': {'kind': 'youtube#video', 'videoId': 'agEjzQLiuGA'},
#    'snippet': {'publishedAt': '2005-11-19T10:32:36Z',
#     'channelId': 'UCY30JRSgfhYXA6i6xX1erWg',
#     'title': 'Power Rangers Theme',
#     'description': "NOTE: Yes, this is the very first video we ever made :) Everyone's favorite TV show's theme song now has a music video. Watch this video in higher quality ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/agEjzQLiuGA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/agEjzQLiuGA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/agEjzQLiuGA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Smosh',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-11-19T10:32:36Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'VG-nEZtaj4JE3hLLcuGJTa2VzJU',
#    'id': {'kind': 'youtube#video', 'videoId': 'LlvUepMa31o'},
#    'snippet': {'publishedAt': '2005-12-10T20:06:19Z',
#     'channelId': 'UC2zb5cQbLabj3U9l3tke1pg',
#     'title': 'Debussy, Clair de lune (piano music)',
#     'description': 'Clair de lune, by Claude Debussy, played by Stephen Malinowski, with a graphical score. FAQ There are several versions of the video on YouTube; the first was ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LlvUepMa31o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LlvUepMa31o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/LlvUepMa31o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'smalin',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-12-10T20:06:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'sVMv4LAmkjKoMjntkCTsLPaRjV4',
#    'id': {'kind': 'youtube#video', 'videoId': 'z4iiyRv_NrQ'},
#    'snippet': {'publishedAt': '2005-12-23T23:52:31Z',
#     'channelId': 'UCCHcEUksSVKsRDH86j77Ntg',
#     'title': 'Bing Bong Brothers',
#     'description': 'The new hit song from the Bing Bong Brothers! Brought to you by: http://www.thelonelyisland.com/ You are free to copy, share and remix this video, under these ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/z4iiyRv_NrQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/z4iiyRv_NrQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/z4iiyRv_NrQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'thelonelyisland',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-12-23T23:52:31Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'k6A0EP-1yzA-EC38_og2IRh-jVE',
#    'id': {'kind': 'youtube#video', 'videoId': 'caCXkevOQp0'},
#    'snippet': {'publishedAt': '2005-11-30T23:41:30Z',
#     'channelId': 'UCKrOk6z473TunIzyYw0CUQw',
#     'title': 'Poppin Battle Poppin John and Randm Rok www.Learn2Bust.com',
#     'description': 'http://www.Learn2Bust.com poppin battle 2on2 @ higher ground Ft. Collins Colorado. Poppin John and Randm Rok SMOKED fooles.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/caCXkevOQp0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/caCXkevOQp0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/caCXkevOQp0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Poppin John SBK',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-11-30T23:41:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'RX3Xjj28tKAYNF-NQkRI6rySqh0',
#    'id': {'kind': 'youtube#video', 'videoId': '8yhd-dpC_7o'},
#    'snippet': {'publishedAt': '2005-12-10T19:46:33Z',
#     'channelId': 'UC2zb5cQbLabj3U9l3tke1pg',
#     'title': 'Scarlatti, Sonata, K. 455, harpsichord',
#     'description': "Domenico Scarlatti's Sonata in G major, K. 455, with bar-graph score. FAQ To download this video or make a contribution to support this project: ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8yhd-dpC_7o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8yhd-dpC_7o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8yhd-dpC_7o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'smalin',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-12-10T19:46:33Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'TleceuYwV9JUHjL3PeAu1_9sjNM',
#    'id': {'kind': 'youtube#video', 'videoId': '4mtfnfQoAco'},
#    'snippet': {'publishedAt': '2005-11-07T17:18:28Z',
#     'channelId': 'UCh6hQvsFLEf3JboY8loS7kA',
#     'title': 'Mattafix - Big City Life',
#     'description': 'Straight from London - Video stream Big City Life Me try fi get by, Pressure nah ease up no matter how hard me try. Big City Life, Here my heart have no base, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4mtfnfQoAco/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4mtfnfQoAco/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4mtfnfQoAco/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'BoscosTina',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-11-07T17:18:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'JbIgUSR2a9jmUY1zQEKUA3p5D2A',
#    'id': {'kind': 'youtube#video', 'videoId': 'pS5peqApgUA'},
#    'snippet': {'publishedAt': '2005-12-28T20:31:08Z',
#     'channelId': 'UCG5iPtFi5voigdtf9wZH9_w',
#     'title': 'Street Fighter - Justin vs Daigo',
#     'description': 'The entire fight from EVO 2004 between Justin (chun-li) and Daigo (ken).',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pS5peqApgUA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pS5peqApgUA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pS5peqApgUA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'foolished',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-12-28T20:31:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'GCtMw7vxI8yUCOwAejcmWuq_0aU',
#    'id': {'kind': 'youtube#video', 'videoId': 'lkFMJ4-ai1I'},
#    'snippet': {'publishedAt': '2005-12-09T15:56:07Z',
#     'channelId': 'UCgY_-shJhjeAbcVhBsdRljA',
#     'title': 'PRIMUS - John THe Fisherman',
#     'description': 'WoW.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lkFMJ4-ai1I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lkFMJ4-ai1I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lkFMJ4-ai1I/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'mMosQuiToN',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-12-09T15:56:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'JGrdCZo0xJSjUDbAKnDwCRy2sA0',
#    'id': {'kind': 'youtube#video', 'videoId': 'kGiYxCUAhks'},
#    'snippet': {'publishedAt': '2005-11-20T09:11:12Z',
#     'channelId': 'UC4SCTmnk_PP4g35Aqg6FeRQ',
#     'title': 'The Nightmare Before Christmas - This is halloween',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kGiYxCUAhks/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/kGiYxCUAhks/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/kGiYxCUAhks/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Leelah',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-11-20T09:11:12Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '7JoHrwsZxR4MsaZ0Wfuu0M8FG9I',
#    'id': {'kind': 'youtube#video', 'videoId': 'ipzR9bhei_o'},
#    'snippet': {'publishedAt': '2005-12-10T20:14:30Z',
#     'channelId': 'UC2zb5cQbLabj3U9l3tke1pg',
#     'title': 'Bach, Toccata and Fugue in D minor, organ',
#     'description': "Bach's most famous organ piece, with a bar-graph score. FAQ Q: I appreciate the work you're doing; how can I support it? A: Thank you! The easiest way to ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ipzR9bhei_o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ipzR9bhei_o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ipzR9bhei_o/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'smalin',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-12-10T20:14:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'dVe8k40pKFYrd8jlr2jzP3yrvkc',
#    'id': {'kind': 'youtube#video', 'videoId': 'ch-ubs_46c8'},
#    'snippet': {'publishedAt': '2005-11-17T10:13:14Z',
#     'channelId': 'UC04XHT-GtHax0orJr-kxiwA',
#     'title': 'Frankie Lymon - Goody Goody (Live)',
#     'description': 'This was recorded back in 1957.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ch-ubs_46c8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ch-ubs_46c8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ch-ubs_46c8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'deviavan',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-11-17T10:13:14Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'gaIhzfVF2QpsnD4y6QlA76ssJ8A',
#    'id': {'kind': 'youtube#video', 'videoId': 'D2kJZOfq7zk'},
#    'snippet': {'publishedAt': '2005-09-02T21:40:19Z',
#     'channelId': 'UClK0eQNc3ksVrRYHYvTBq7g',
#     'title': 'Urban Ninja',
#     'description': 'Urban Ninja These are not my movies. They are part of http://www.emcmonkeys.com. Please give them a visit.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/D2kJZOfq7zk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/D2kJZOfq7zk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/D2kJZOfq7zk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'mrWoot',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-09-02T21:40:19Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'GG5mQt68x-USudoJ1o_QNwP1q_4',
#    'id': {'kind': 'youtube#video', 'videoId': 'i0fAEJQtqnU'},
#    'snippet': {'publishedAt': '2005-12-17T18:49:28Z',
#     'channelId': 'UCrlYN8_xAzrZfUbUwMIrSIQ',
#     'title': 'Maxwell Video Fortunate',
#     'description': 'Fortunate Video.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/i0fAEJQtqnU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/i0fAEJQtqnU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/i0fAEJQtqnU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'memeluvsutru',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2005-12-17T18:49:28Z'}}]}

# %%
for item in res['items']:
    print(item['snippet']['title'])
# Out:
# Mortal Kombat Theme
# celine dion ft. josh groban, the prayer
# Just 2 Guyz
# Baltimora - Tarzan Boy
# Stork Patrol
# Ka-Blamo!
# Aaron Kyro www.brailleskateboarding.com
# Power Rangers Theme
# Debussy, Clair de lune (piano music)
# Bing Bong Brothers
# Poppin Battle Poppin John and Randm Rok www.Learn2Bust.com
# Scarlatti, Sonata, K. 455, harpsichord
# Mattafix - Big City Life
# Street Fighter - Justin vs Daigo
# PRIMUS - John THe Fisherman
# The Nightmare Before Christmas - This is halloween
# Bach, Toccata and Fugue in D minor, organ
# Frankie Lymon - Goody Goody (Live)
# Urban Ninja
# Maxwell Video Fortunate

# %%
for item in sorted(res['items'],key = lambda x:x['snippet']['publishedAt']):
    print("Title:",item['snippet']['title'],"|",
          "Published At:",item['snippet']['publishedAt'],"|",
          "Video ID:",item['id']['videoId'])
# Out:
# Title: Urban Ninja | Published At: 2005-09-02T21:40:19Z | Video ID: D2kJZOfq7zk
# Title: Baltimora - Tarzan Boy | Published At: 2005-11-02T22:02:48Z | Video ID: _r0n9Dv6XnY
# Title: Mattafix - Big City Life | Published At: 2005-11-07T17:18:28Z | Video ID: 4mtfnfQoAco
# Title: celine dion ft. josh groban, the prayer | Published At: 2005-11-14T09:45:25Z | Video ID: jhxIjRO6WjI
# Title: Frankie Lymon - Goody Goody (Live) | Published At: 2005-11-17T10:13:14Z | Video ID: ch-ubs_46c8
# Title: Power Rangers Theme | Published At: 2005-11-19T10:32:36Z | Video ID: agEjzQLiuGA
# Title: Mortal Kombat Theme | Published At: 2005-11-19T10:38:22Z | Video ID: UMf40daefsI
# Title: The Nightmare Before Christmas - This is halloween | Published At: 2005-11-20T09:11:12Z | Video ID: kGiYxCUAhks
# Title: Poppin Battle Poppin John and Randm Rok www.Learn2Bust.com | Published At: 2005-11-30T23:41:30Z | Video ID: caCXkevOQp0
# Title: PRIMUS - John THe Fisherman | Published At: 2005-12-09T15:56:07Z | Video ID: lkFMJ4-ai1I
# Title: Scarlatti, Sonata, K. 455, harpsichord | Published At: 2005-12-10T19:46:33Z | Video ID: 8yhd-dpC_7o
# Title: Debussy, Clair de lune (piano music) | Published At: 2005-12-10T20:06:19Z | Video ID: LlvUepMa31o
# Title: Bach, Toccata and Fugue in D minor, organ | Published At: 2005-12-10T20:14:30Z | Video ID: ipzR9bhei_o
# Title: Maxwell Video Fortunate | Published At: 2005-12-17T18:49:28Z | Video ID: i0fAEJQtqnU
# Title: Bing Bong Brothers | Published At: 2005-12-23T23:52:31Z | Video ID: z4iiyRv_NrQ
# Title: Just 2 Guyz | Published At: 2005-12-24T01:13:43Z | Video ID: Nt2OVAgkHBc
# Title: Ka-Blamo! | Published At: 2005-12-24T02:30:34Z | Video ID: qn7duAZjP8w
# Title: Stork Patrol | Published At: 2005-12-24T02:45:00Z | Video ID: rH9giCg3Nro
# Title: Aaron Kyro www.brailleskateboarding.com | Published At: 2005-12-28T19:33:46Z | Video ID: m1Q8Dirdzxk
# Title: Street Fighter - Justin vs Daigo | Published At: 2005-12-28T20:31:08Z | Video ID: pS5peqApgUA
