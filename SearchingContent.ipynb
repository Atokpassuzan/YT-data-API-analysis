# %%
# First pip install google-api-python-client

# %%
api_key = "AIzaSyDxJbSEPodYNzB6Fuk4hsZHnwH08J8uc1I"

# %%
from apiclient.discovery import build

# %%
youtube = build('youtube','v3',developerKey=api_key)

# %%
type(youtube)
# Out:
# googleapiclient.discovery.Resource

# %%
req = youtube.search().list(q='avengers',part='snippet',type='video',maxResults = 20 )

# %%
type(req)
# Out:
# googleapiclient.http.HttpRequest

# %%
res = req.execute()

# %%
res
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'FKUdwqW5iZSuszvRQoiS6vvmWhk',
#  'nextPageToken': 'CBQQAA',
#  'regionCode': 'NP',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'bAMZbF7QPezmNp-8qkiiJM2rE_Q',
#    'id': {'kind': 'youtube#video', 'videoId': 'Kt6wsx2Bp3Q'},
#    'snippet': {'publishedAt': '2020-05-11T00:46:26Z',
#     'channelId': 'UCbWPYsyJX1-7uvfOw3LkLqw',
#     'title': 'Marvel Avengers HulkBuster Ultimate HQ And Iron Man Headquarters! Get Away Thanos! #ToyMartTV',
#     'description': 'Marvel Avengers HulkBuster Ultimate HQ And Iron Man Headquarters! Get Away Thanos! Hello~! Thank you for visiting here and we hope you enjoy our videos~ ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Kt6wsx2Bp3Q/default_live.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Kt6wsx2Bp3Q/mqdefault_live.jpg',
#       'width': 320,
# ...

# %%
len(res['items'])  # Default no. of items is 5 .We can set this to any value.(Above we have set maxResults =20)
# Out:
# 20

# %%
res['items'][0] #To check the first item
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'bAMZbF7QPezmNp-8qkiiJM2rE_Q',
#  'id': {'kind': 'youtube#video', 'videoId': 'Kt6wsx2Bp3Q'},
#  'snippet': {'publishedAt': '2020-05-11T00:46:26Z',
#   'channelId': 'UCbWPYsyJX1-7uvfOw3LkLqw',
#   'title': 'Marvel Avengers HulkBuster Ultimate HQ And Iron Man Headquarters! Get Away Thanos! #ToyMartTV',
#   'description': 'Marvel Avengers HulkBuster Ultimate HQ And Iron Man Headquarters! Get Away Thanos! Hello~! Thank you for visiting here and we hope you enjoy our videos~ ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Kt6wsx2Bp3Q/default_live.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Kt6wsx2Bp3Q/mqdefault_live.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Kt6wsx2Bp3Q/hqdefault_live.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'ToyMart TV',
#   'liveBroadcastContent': 'live',
# ...

# %%
for item in res['items']:
    print(item['snippet']['title'])
# Out:
# Marvel Avengers HulkBuster Ultimate HQ And Iron Man Headquarters! Get Away Thanos! #ToyMartTV
# Thor vs Hulk - Fight Scene - The Avengers (2012) Movie Clip HD
# WWE 2K19 Giant Avengers Destroy Coronavirus!
# MARVEL AVENGERS HULK SMASH COLLECTION~! Thor Thunder and Lightning Makes Hulk Bigger!-Charles toy
# Black Panther 2 Marvel Announcement Breakdown - Avengers Easter Eggs
# AVENGERS 4: ENDGAME All Movie Clips (2019)
# Avengers Endgame Deleted Scene - Iron Man Alternate Ending Scene Breakdown
# MARVEL AVENGERS INFINITY WAR FIGURES~ HULK, SPIDER MAN, IRON MAN, CAPTAIN AMERICA -Charles toy
# Hulk contra Thanos - El Final Alternativo de los Vengadores | Avengers Infinity war - HD
# The Avengers - &quot;I&#39;m Always Angry&quot; - Hulk SMASH Scene - Movie CLIP HD
# Team Iron Man vs Team Cap - Airport Battle Scene - Captain America: Civil War - Movie CLIP HD
# Avengers EndGaMe 2019 Full Movie in Hindi Dubbed
# Hulk Saves Iron Man - Final Battle Scene - The Avengers (2012) Movie Clip HD
# ...
